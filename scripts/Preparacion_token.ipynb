# %%
# Contamos únicamente con 8091 imágenes
import numpy as np
import pandas as pd
from pathlib import Path

# %%
def GenerarListaImagenes(str_Path):

    np_Archivos = np.empty([0])
    for file in Path(str_Path+'Flicker8k_Dataset').glob('*'):
        # print(file)
        # list_Archivos.append(file.name)
        np_Archivos = np.append(np_Archivos, [file.name])

    # Cantidad de imágenes disponibles
    # len(np_Archivos)

    # Se construye el dataframe con base en el arreglo de campos
    columns = ['id_imagen']
    df = pd.DataFrame(data=np_Archivos, columns=columns)
    df.to_csv(str_Path+'/Preprocessing/lista_imagenes.csv', index=False, header=True)


def FormatearDescripciones(str_Path, str_Archiv_Origen, str_NombreCsv):

    # Recorremos el archivo para eliminar los tabs
    str_Fuente = str_Path + '/Flickr8k_text/' + str_Archiv_Origen
    str_Destino = str_Path + '/Flickr8k_text/' + 'Tmp_' + str_Archiv_Origen
    with open(str_Fuente) as Origen, open(str_Destino, 'w') as Destino:
        for line in Origen:
            Destino.write(line.replace('\t', ' '))

    # Recorremos línea a línea el archivo para encontrar en qué punto se separa
    # el id de imagen del texto
    np_Array = np.empty([0,3])
    with open(str_Destino) as file:
        for line in file:
            nbr_Index = line.find(' ')
            line = line.replace('\n', '')
            line = line.replace(' .', '')
            # print(nbr_Index)
            str_Substr1 = line[0:nbr_Index-2]
            str_Substr2 = line[nbr_Index-1]
            str_Substr3 = line[nbr_Index+1:]
            # print(str_Substr2)
            # list_IdImagenes.append(str_Substr1)
            # list_Descr.append(str_Substr2)
            np_Array = np.append(np_Array, [[str_Substr1, str_Substr2, str_Substr3]], axis=0)

    # Se construye el dataframe con base en el arreglo de campos
    columns = ['id_imagen', 'id_seqq', 'descr']
    df = pd.DataFrame(data=np_Array, columns=columns)
    df.to_csv(str_Path+'/Preprocessing/'+str_NombreCsv, index=False, header=True)

# %%
# Formateamos los datos para un análisis de los datos
str_Path = '/Users/cynthia/github/Img-Gen/' 
# GenerarListaImagenes(str_Path)
# FormatearDescripciones(str_Path, 'Flickr8k.token.txt', 'Token.csv') # Se tarda

# %%
#GenerarListaImagenes(str_Path)

# %%
#FormatearDescripciones(str_Path, 'Flickr8k.token.txt', 'Token.csv')

# %%
# Se toma el dataset generado en la celda anterior
df_Tokens = pd.read_csv(str_Path+'/Preprocessing/Token.csv')

# %%
# A partir de lo anterior, se puede generar este data frame
df_Tokens = pd.read_csv(str_Path+'/Preprocessing/Token.csv')
df_Tokens
# Out:
#                        id_imagen  id_seqq  \
# 0      1000268201_693b08cb0e.jpg        0
# 1      1000268201_693b08cb0e.jpg        1
# 2      1000268201_693b08cb0e.jpg        2
# 3      1000268201_693b08cb0e.jpg        3
# 4      1000268201_693b08cb0e.jpg        4
# 5      1001773457_577c3a7d70.jpg        0
# 6      1001773457_577c3a7d70.jpg        1
# 7      1001773457_577c3a7d70.jpg        2
# 8      1001773457_577c3a7d70.jpg        3
# 9      1001773457_577c3a7d70.jpg        4
# 10     1002674143_1b742ab4b8.jpg        0
# 11     1002674143_1b742ab4b8.jpg        1
# 12     1002674143_1b742ab4b8.jpg        2
# 13     1002674143_1b742ab4b8.jpg        3
# 14     1002674143_1b742ab4b8.jpg        4
# 15     1003163366_44323f5815.jpg        0
# 16     1003163366_44323f5815.jpg        1
# 17     1003163366_44323f5815.jpg        2
# 18     1003163366_44323f5815.jpg        3
# 19     1003163366_44323f5815.jpg        4
# 20     1007129816_e794419615.jpg        0
# 21     1007129816_e794419615.jpg        1
# 22     1007129816_e794419615.jpg        2
# 23     1007129816_e794419615.jpg        3
# 24     1007129816_e794419615.jpg        4
# 25     1007320043_627395c3d8.jpg        0
# 26     1007320043_627395c3d8.jpg        1
# 27     1007320043_627395c3d8.jpg        2
# 28     1007320043_627395c3d8.jpg        3
# 29     1007320043_627395c3d8.jpg        4
# ...                          ...      ...
# 40430   989851184_9ef368e520.jpg        0
# 40431   989851184_9ef368e520.jpg        1
# 40432   989851184_9ef368e520.jpg        2
# 40433   989851184_9ef368e520.jpg        3
# 40434   989851184_9ef368e520.jpg        4
# 40435   990890291_afc72be141.jpg        0
# 40436   990890291_afc72be141.jpg        1
# 40437   990890291_afc72be141.jpg        2
# 40438   990890291_afc72be141.jpg        3
# 40439   990890291_afc72be141.jpg        4
# 40440    99171998_7cc800ceef.jpg        0
# 40441    99171998_7cc800ceef.jpg        1
# 40442    99171998_7cc800ceef.jpg        2
# 40443    99171998_7cc800ceef.jpg        3
# 40444    99171998_7cc800ceef.jpg        4
# 40445    99679241_adc853a5c0.jpg        0
# 40446    99679241_adc853a5c0.jpg        1
# 40447    99679241_adc853a5c0.jpg        2
# 40448    99679241_adc853a5c0.jpg        3
# 40449    99679241_adc853a5c0.jpg        4
# 40450   997338199_7343367d7f.jpg        0
# 40451   997338199_7343367d7f.jpg        1
# 40452   997338199_7343367d7f.jpg        2
# 40453   997338199_7343367d7f.jpg        3
# 40454   997338199_7343367d7f.jpg        4
# 40455   997722733_0cb5439472.jpg        0
# 40456   997722733_0cb5439472.jpg        1
# 40457   997722733_0cb5439472.jpg        2
# 40458   997722733_0cb5439472.jpg        3
# 40459   997722733_0cb5439472.jpg        4
#
#                                                    descr
# 0      A child in a pink dress is climbing up a set o...
# 1                    A girl going into a wooden building
# 2         A little girl climbing into a wooden playhouse
# 3      A little girl climbing the stairs to her playh...
# 4      A little girl in a pink dress going into a woo...
# 5             A black dog and a spotted dog are fighting
# 6      A black dog and a tri-colored dog playing with...
# 7      A black dog and a white dog with brown spots a...
# 8      Two dogs of different breeds looking at each o...
# 9          Two dogs on pavement moving toward each other
# 10     A little girl covered in paint sits in front o...
# 11     A little girl is sitting in front of a large p...
# 12     A small girl in the grass plays with fingerpai...
# 13     There is a girl with pigtails sitting in front...
# 14     Young girl with pigtails painting outside in t...
# 15       A man lays on a bench while his dog sits by him
# 16     A man lays on the bench to which a white dog i...
# 17     a man sleeping on a bench outside with a white...
# 18     A shirtless man lies on a park bench with his dog
# 19     man laying on bench holding leash of dog sitti...
# 20          A man in an orange hat starring at something
# 21                 A man wears an orange hat and glasses
# 22     A man with gauges and glasses is wearing a Bli...
# 23     A man with glasses is wearing a beer can croch...
# 24     The man with pierced ears is wearing glasses a...
# 25                         A child playing on a rope net
# 26                  A little girl climbing on red roping
# 27     A little girl in pink climbs a rope bridge at ...
# 28     A small child grips onto the red ropes at the ...
# 29     The small child climbs on a red ropes on a pla...
# ...                                                  ...
# 40430            A black dog has a dumbbell in his mouth
# 40431  A black dog has a dumbbell in his mouth lookin...
# 40432  A black dog holding a weight in its mouth stan...
# 40433  A black dog holds a small white dumbbell in it...
# 40434  The black dog has a toy in its mouth and a per...
# 40435  A man does a wheelie on his bicycle on the sid...
# 40436        A man is doing a wheelie on a mountain bike
# 40437       A man on a bicycle is on only the back wheel
# 40438  Asian man in orange hat is popping a wheelie o...
# 40439          Man on a bicycle riding on only one wheel
# 40440         A group is sitting around a snowy crevasse
# 40441        A group of people sit atop a snowy mountain
# 40442  A group of people sit in the snow overlooking ...
# 40443                Five children getting ready to sled
# 40444       Five people are sitting together in the snow
# 40445  A grey bird stands majestically on a beach whi...
# 40446      A large bird stands in the water on the beach
# 40447  A tall bird is standing on the sand beside the...
# 40448         A water bird standing at the ocean 's edge
# 40449  A white crane stands tall as it looks out upon...
# 40450                  A person stands near golden walls
# 40451          a woman behind a scrolled wall is writing
# 40452      A woman standing near a decorated wall writes
# 40453         The walls are covered in gold and patterns
# 40454  Woman writing on a pad in room with gold , dec...
# 40455           A man in a pink shirt climbs a rock face
# 40456             A man is rock climbing high in the air
# 40457  A person in a red shirt climbing up a rock fac...
# 40458                      A rock climber in a red shirt
# 40459   A rock climber practices on a rock climbing wall
#
# [40460 rows x 3 columns]

# %%
# Nos quedamos únicamente con la primer descipción de cada imagen
df_Reducido = df_Tokens.loc[df_Tokens['id_seqq'] == 2]

# Guardamos este csv reducido a una descripción por imagen
df_Reducido.to_csv(str_Path+'/Preprocessing/Token_Reducido.csv', index=False, header=True)

# %%
# Y este es el data frame reducido (mismas columnas, se eliminan filas)
df_Reducido
# Out:
#                        id_imagen  id_seqq  \
# 2      1000268201_693b08cb0e.jpg        2
# 7      1001773457_577c3a7d70.jpg        2
# 12     1002674143_1b742ab4b8.jpg        2
# 17     1003163366_44323f5815.jpg        2
# 22     1007129816_e794419615.jpg        2
# 27     1007320043_627395c3d8.jpg        2
# 32     1009434119_febe49276a.jpg        2
# 37     1012212859_01547e3f17.jpg        2
# 42     1015118661_980735411b.jpg        2
# 47     1015584366_dfcec3c85a.jpg        2
# 52      101654506_8eb26cfb60.jpg        2
# 57      101669240_b2d3e7f17b.jpg        2
# 62     1016887272_03199f49c4.jpg        2
# 67     1019077836_6fc9b15408.jpg        2
# 72     1019604187_d087bf9a5f.jpg        2
# 77     1020651753_06077ec457.jpg        2
# 82     1022454332_6af2c1449a.jpg        2
# 87     1022454428_b6b660a67b.jpg        2
# 92     1022975728_75515238d8.jpg        2
# 97      102351840_323e3de834.jpg        2
# 102    1024138940_f1fefbdce1.jpg        2
# 107     102455176_5f8ead62d5.jpg        2
# 112    1026685415_0431cbf574.jpg        2
# 117    1028205764_7e8df9a2ea.jpg        2
# 122    1030985833_b0902ea560.jpg        2
# 127     103106960_e8a41d64f8.jpg        2
# 132     103195344_5d2dc613a3.jpg        2
# 137     103205630_682ca7285b.jpg        2
# 142    1032122270_ea6f0beedb.jpg        2
# 147    1032460886_4a598ed535.jpg        2
# ...                          ...      ...
# 40312   965444691_fe7e85bf0e.jpg        2
# 40317   967719295_3257695095.jpg        2
# 40322   968081289_cdba83ce2e.jpg        2
# 40327    96973080_783e375945.jpg        2
# 40332    96978713_775d66a18d.jpg        2
# 40337    96985174_31d4c6f06d.jpg        2
# 40342   970641406_9a20ee636a.jpg        2
# 40347    97105139_fae46fe8ef.jpg        2
# 40352   972381743_5677b420ab.jpg        2
# 40357   973827791_467d83986e.jpg        2
# 40362    97406261_5eea044056.jpg        2
# 40367   974924582_10bed89b8d.jpg        2
# 40372   975131015_9acd25db9c.jpg        2
# 40377    97577988_65e2eae14a.jpg        2
# 40382   976392326_082dafc3c5.jpg        2
# 40387    97731718_eb7ba71fd3.jpg        2
# 40392   977856234_0d9caee7b2.jpg        2
# 40397   978580450_e862715aba.jpg        2
# 40402   979201222_75b6456d34.jpg        2
# 40407   979383193_0a542a059d.jpg        2
# 40412    98377566_e4674d1ebd.jpg        2
# 40417   985067019_705fe4a4cc.jpg        2
# 40422   987907964_5a06a63609.jpg        2
# 40427   989754491_7e53fb4586.jpg        2
# 40432   989851184_9ef368e520.jpg        2
# 40437   990890291_afc72be141.jpg        2
# 40442    99171998_7cc800ceef.jpg        2
# 40447    99679241_adc853a5c0.jpg        2
# 40452   997338199_7343367d7f.jpg        2
# 40457   997722733_0cb5439472.jpg        2
#
#                                                    descr
# 2         A little girl climbing into a wooden playhouse
# 7      A black dog and a white dog with brown spots a...
# 12     A small girl in the grass plays with fingerpai...
# 17     a man sleeping on a bench outside with a white...
# 22     A man with gauges and glasses is wearing a Bli...
# 27     A little girl in pink climbs a rope bridge at ...
# 32              A Boston terrier is running in the grass
# 37     Dog with orange ball at feet , stands on shore...
# 42                     A young boy runs aross the street
# 47                  A large black dog leaps a fallen log
# 52                            A dog running through snow
# 57     A person wearing skis looking at framed pictur...
# 62     A group of people climbing a rock while one ma...
# 67      A brown dog running on a lawn near a garden hose
# 72        A white dog is about to catch a yellow dog toy
# 77                A dog leaps to catch a ball in a field
# 82                A little boy at a lake watching a duck
# 87     A couple with their newborn baby sitting under...
# 92                           A dog splashes in the water
# 97       A person in the snow drilling a hole in the ice
# 102            Two dogs playing in the sand at the beach
# 107            An ice climber scaling a frozen waterfall
# 112              A black dog has a blue toy in its mouth
# 117          A man and child kayak through gentle waters
# 122    A brown and black lab are outside and the blac...
# 127      A young kid playing the goalie in a hockey rink
# 132                       a man sits near a large statue
# 137    two men setting up a blue ice fishing hut on a...
# 142    Three dogs are standing in the grass and a per...
# 147        A man stands in front of a very tall building
# ...                                                  ...
# 40312                        A man in black holds a baby
# 40317  A light colored dog jumping off the back of a ...
# 40322       Two boys jumping off the pier into the water
# 40327                  A dog is running through the snow
# 40332  People walk across a rope bridge over a rocky ...
# 40337  A man with ski poles stands in front of a moun...
# 40342  a group of people standing on a small balcony ...
# 40347  Two men in robes wave at an approaching jeep t...
# 40352  a performer dancing in the streets wearing an ...
# 40357  A woman is throwing a bucket of water over a b...
# 40362              A dog and cat are fighting on a chair
# 40367  A child playing with a water hose while a woma...
# 40372  A boy pets a sleeping tiger while another tige...
# 40377  A person in orange climbs a sheer cliff face c...
# 40382                      two girls sit on a large rock
# 40387  Black and white horses carry a cart with peopl...
# 40392  A long-haired dog wearing a pink vest and running
# 40397                   a child submerges from the water
# 40402      Two girls in shorts walk towards casino signs
# 40407  Six children , all with black hair , sit at a ...
# 40412               Two small dogs are in a cage outside
# 40417               A boy is sliding down in a red shirt
# 40422      Two cocker spaniels running through the grass
# 40427  A red haired girl making a peace sign is weari...
# 40432  A black dog holding a weight in its mouth stan...
# 40437       A man on a bicycle is on only the back wheel
# 40442  A group of people sit in the snow overlooking ...
# 40447  A tall bird is standing on the sand beside the...
# 40452      A woman standing near a decorated wall writes
# 40457  A person in a red shirt climbing up a rock fac...
#
# [8092 rows x 3 columns]

# %%
df_Reducido.dtypes
# Out:
# id_imagen    object
# id_seqq       int64
# descr        object
# dtype: object

# %%
type(df_Reducido)
# Out:
# pandas.core.frame.DataFrame

# %%
df = df_Reducido['descr'].astype(str) #.contains('dog', regex=True)
df_new = df.to_frame()
df_new.shape
# Out:
# (8092, 1)

# %%
#Perros:
dog = df_new['descr'].str.contains('dog|dogs', case=True, regex=True)
#(dog==False).count()
dog.value_counts(True)
# Out:
# False    0.770638
# True     0.229362
# Name: descr, dtype: float64

# %%
#Gatos:
cat = df_new['descr'].str.contains('cat|cats', case=True, regex=True)
#(dog==False).count()
cat.value_counts(True)
# Out:
# False    0.982699
# True     0.017301
# Name: descr, dtype: float64

# %%
#Personas:
people = df_new['descr'].str.contains('woman|men|children', case=True, regex=True)
#(dog==False).count()
people.value_counts(True)
# Out:
# False    0.832921
# True     0.167079
# Name: descr, dtype: float64

# %%
#Manipulación de texto
import nltk
import os
import nltk.corpus
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cynthia\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
text = df_Reducido['descr'].astype('str')

# %%
#Convertirlo a string 
text_str = text.to_string()
type(text_str)
# Out:
# str

# %%
#Eliminar los valores numéricos:
text_sin_number = ''.join([i for i in text_str if not i.isdigit()])
text_sin_number
# Out:
# '           A little girl climbing into a wooden playhouse\n        A black dog and a white dog with brown spots a...\n       A small girl in the grass plays with fingerpai...\n       a man sleeping on a bench outside with a white...\n       A man with gauges and glasses is wearing a Bli...\n       A little girl in pink climbs a rope bridge at ...\n                A Boston terrier is running in the grass\n       Dog with orange ball at feet , stands on shore...\n                       A young boy runs aross the street\n                    A large black dog leaps a fallen log\n                              A dog running through snow\n       A person wearing skis looking at framed pictur...\n       A group of people climbing a rock while one ma...\n        A brown dog running on a lawn near a garden hose\n          A white dog is about to catch a yellow dog toy\n                  A dog leaps to catch a ball in a field\n                  A little boy at a lake watching a duck\n       A couple with their newborn baby sitting under...\n                             A dog splashes in the water\n         A person in the snow drilling a hole in the ice\n              Two dogs playing in the sand at the beach\n              An ice climber scaling a frozen waterfall\n                A black dog has a blue toy in its mouth\n            A man and child kayak through gentle waters\n      A brown and black lab are outside and the blac...\n        A young kid playing the goalie in a hockey rink\n                         a man sits near a large statue\n      two men setting up a blue ice fishing hut on a...\n      Three dogs are standing in the grass and a per...\n          A man stands in front of a very tall building\n      A small boy putting something in his mouth wit...\n             Three people hang out on top of a big hill\n      A boy looks over a railing at the many boats a...\n              A multiracial couple posing for a picture\n            A television with a picture of a girl on it\n              A group of teens sit on a wall by a beach\n      A little boy skateboarder is doing a trick on ...\n                    A woman paddles a boat down a river\n      a girl with pigtails is playing in the ocean b...\n      A group of young children playing pillow fight...\n          Two construction workers sitting on an I-beam\n                              Two boys play in a puddle\n      A woman is signaling is to traffic , as seen f...\n      A young girl on a train reads a book about tra...\n                            Two dogs playing on a beach\n      A kid jumps off the diving board and into the ...\n               A man puts his shirt on near an elevator\n                        A tan dog runs on a sandy beach\n      A young boy in swimming trunks is walking with...\n         A skier is overlooking a snow-covered mountain\n         a black and white dog jumps to get the Frisbee\n      A man laying down in middle of street during h...\n            One dog is chasing another one on the beach\n      A dog is jumping to catch a object thrown at it ,\n       People are watching hot air balloons in the park\n       A young boy in a helmet rides a bike on the road\n      A group of people sit around a table outside o...\n         a man playing with two black dogs on the beach\n                            A boy is covered in bubbles\n      A boy rides down a slide into a small backyard...\n      A man in water throwing a little boy up in the...\n      Two young boys are looking at the camera , one...\n           A girl holding a horse \'s lead behind a fire\n      A large skinny dog stands near two smaller dog...\n                    A man and a woman sitting on a dock\n                 A white dog has its head on the ground\n                       The girl is climbing a rock wall\n        A teenage boy is jumping on an inflatable slide\n      Several children playing on a Polaris vehicle ...\n      A young woman in a red sequined costu ...

# %%
#Tokenizar las palabras
token = word_tokenize(text_sin_number)
token
# Out:
# ['A',
#  'little',
#  'girl',
#  'climbing',
#  'into',
#  'a',
#  'wooden',
#  'playhouse',
#  'A',
#  'black',
#  'dog',
#  'and',
#  'a',
#  'white',
#  'dog',
#  'with',
#  'brown',
#  'spots',
#  'a',
#  '...',
#  'A',
#  'small',
#  'girl',
#  'in',
#  'the',
#  'grass',
#  'plays',
#  'with',
#  'fingerpai',
#  '...',
#  'a',
#  'man',
#  'sleeping',
#  'on',
#  'a',
#  'bench',
#  'outside',
#  'with',
#  'a',
#  'white',
#  '...',
#  'A',
#  'man',
#  'with',
#  'gauges',
#  'and',
#  'glasses',
#  'is',
#  'wearing',
#  'a',
#  'Bli',
#  '...',
#  'A',
#  'little',
#  'girl',
#  'in',
#  'pink',
#  'climbs',
#  'a',
#  'rope',
#  'bridge',
#  'at',
#  '...',
#  'A',
#  'Boston',
#  'terrier',
#  'is',
#  'running',
#  'in',
#  'the',
#  'grass',
#  'Dog',
#  'with',
#  'orange',
#  'ball',
#  'at',
#  'feet',
#  ',',
#  'stands',
#  'on',
#  'shore',
#  '...',
#  'A',
#  'young',
#  'boy',
#  'runs',
#  'aross',
#  'the',
#  'street',
#  'A',
#  'large',
#  'black',
#  'dog',
#  'leaps',
#  'a',
#  'fallen',
#  'log',
#  'A',
#  'dog',
#  'running',
#  'through',
#  'snow',
#  'A',
#  'person',
#  'wearing',
#  'skis',
#  'looking',
#  'at',
#  'framed',
#  'pictur',
#  '...',
#  'A',
#  'group',
#  'of',
#  'people',
#  'climbing',
#  'a',
#  'rock',
#  'while',
#  'one',
#  'ma',
#  '...',
#  'A',
#  'brown',
#  'dog',
#  'running',
#  'on',
#  'a',
#  'lawn',
#  'near',
#  'a',
#  'garden',
#  'hose',
#  'A',
#  'white',
#  'dog',
#  'is',
#  'about',
#  'to',
#  'catch',
#  'a',
#  'yellow',
#  'dog',
#  'toy',
#  'A',
#  'dog',
#  'leaps',
#  'to',
#  'catch',
#  'a',
#  'ball',
#  'in',
#  'a',
#  'field',
#  'A',
#  'little',
#  'boy',
#  'at',
#  'a',
#  'lake',
#  'watching',
#  'a',
#  'duck',
#  'A',
#  'couple',
#  'with',
#  'their',
#  'newborn',
#  'baby',
#  'sitting',
#  'under',
#  '...',
#  'A',
#  'dog',
#  'splashes',
#  'in',
#  'the',
#  'water',
#  'A',
#  'person',
#  'in',
#  'the',
#  'snow',
#  'drilling',
#  'a',
#  'hole',
#  'in',
#  'the',
#  'ice',
#  'Two',
#  'dogs',
#  'playing',
#  'in',
#  'the',
#  'sand',
#  'at',
#  'the',
#  'beach',
#  'An',
#  'ice',
#  'climber',
#  'scaling',
#  'a',
#  'frozen',
#  'waterfall',
#  'A',
#  'black',
#  'dog',
#  'has',
#  'a',
#  'blue',
#  'toy',
#  'in',
#  'its',
#  'mouth',
#  'A',
#  'man',
#  'and',
#  'child',
#  'kayak',
#  'through',
#  'gentle',
#  'waters',
#  'A',
#  'brown',
#  'and',
#  'black',
#  'lab',
#  'are',
#  'outside',
#  'and',
#  'the',
#  'blac',
#  '...',
#  'A',
#  'young',
#  'kid',
#  'playing',
#  'the',
#  'goalie',
#  'in',
#  'a',
#  'hockey',
#  'rink',
#  'a',
#  'man',
#  'sits',
#  'near',
#  'a',
#  'large',
#  'statue',
#  'two',
#  'men',
#  'setting',
#  'up',
#  'a',
#  'blue',
#  'ice',
#  'fishing',
#  'hut',
#  'on',
#  'a',
#  '...',
#  'Three',
#  'dogs',
#  'are',
#  'standing',
#  'in',
#  'the',
#  'grass',
#  'and',
#  'a',
#  'per',
#  '...',
#  'A',
#  'man',
#  'stands',
#  'in',
#  'front',
#  'of',
#  'a',
#  'very',
#  'tall',
#  'building',
#  'A',
#  'small',
#  'boy',
#  'putting',
#  'something',
#  'in',
#  'his',
#  'mouth',
#  'wit',
#  '...',
#  'Three',
#  'people',
#  'hang',
#  'out',
#  'on',
#  'top',
#  'of',
#  'a',
#  'big',
#  'hill',
#  'A',
#  'boy',
#  'looks',
#  'over',
#  'a',
#  'railing',
#  'at',
#  'the',
#  'many',
#  'boats',
#  'a',
#  '...',
#  'A',
#  'multiracial',
#  'couple',
#  'posing',
#  'for',
#  'a',
#  'picture',
#  'A',
#  'television',
#  'with',
#  'a',
#  'picture',
#  'of',
#  'a',
#  'girl',
#  'on',
#  'it',
#  'A',
#  'group',
#  'of',
#  'teens',
#  'sit',
#  'on',
#  'a',
#  'wall',
#  'by',
#  'a',
#  'beach',
#  'A',
#  'little',
#  'boy',
#  'skateboarder',
#  'is',
#  'doing',
#  'a',
#  'trick',
#  'on',
#  '...',
#  'A',
#  'woman',
#  'paddles',
#  'a',
#  'boat',
#  'down',
#  'a',
#  'river',
#  'a',
#  'girl',
#  'with',
#  'pigtails',
#  'is',
#  'playing',
#  'in',
#  'the',
#  'ocean',
#  'b',
#  '...',
#  'A',
#  'group',
#  'of',
#  'young',
#  'children',
#  'playing',
#  'pillow',
#  'fight',
#  '...',
#  'Two',
#  'construction',
#  'workers',
#  'sitting',
#  'on',
#  'an',
#  'I-beam',
#  'Two',
#  'boys',
#  'play',
#  'in',
#  'a',
#  'puddle',
#  'A',
#  'woman',
#  'is',
#  'signaling',
#  'is',
#  'to',
#  'traffic',
#  ',',
#  'as',
#  'seen',
#  'f',
#  '...',
#  'A',
#  'young',
#  'girl',
#  'on',
#  'a',
#  'train',
#  'reads',
#  'a',
#  'book',
#  'about',
#  'tra',
#  '...',
#  'Two',
#  'dogs',
#  'playing',
#  'on',
#  'a',
#  'beach',
#  'A',
#  'kid',
#  'jumps',
#  'off',
#  'the',
#  'diving',
#  'board',
#  'and',
#  'into',
#  'the',
#  '...',
#  'A',
#  'man',
#  'puts',
#  'his',
#  'shirt',
#  'on',
#  'near',
#  'an',
#  'elevator',
#  'A',
#  'tan',
#  'dog',
#  'runs',
#  'on',
#  'a',
#  'sandy',
#  'beach',
#  'A',
#  'young',
#  'boy',
#  'in',
#  'swimming',
#  'trunks',
#  'is',
#  'walking',
#  'with',
#  '...',
#  'A',
#  'skier',
#  'is',
#  'overlooking',
#  'a',
#  'snow-covered',
#  'mountain',
#  'a',
#  'black',
#  'and',
#  'white',
#  'dog',
#  'jumps',
#  'to',
#  'get',
#  'the',
#  'Frisbee',
#  'A',
#  'man',
#  'laying',
#  'down',
#  'in',
#  'middle',
#  'of',
#  'street',
#  'during',
#  'h',
#  '...',
#  'One',
#  'dog',
#  'is',
#  'chasing',
#  'another',
#  'one',
#  'on',
#  'the',
#  'beach',
#  'A',
#  'dog',
#  'is',
#  'jumping',
#  'to',
#  'catch',
#  'a',
#  'object',
#  'thrown',
#  'at',
#  'it',
#  ',',
#  'People',
#  'are',
#  'watching',
#  'hot',
#  'air',
#  'balloons',
#  'in',
#  'the',
#  'park',
#  'A',
#  'young',
#  'boy',
#  'in',
#  'a',
#  'helmet',
#  'rides',
#  'a',
#  'bike',
#  'on',
#  'the',
#  'road',
#  'A',
#  'group',
#  'of',
#  'people',
#  'sit',
#  'around',
#  'a',
#  'table',
#  'outside',
#  'o',
#  '...',
#  'a',
#  'man',
#  'playing',
#  'with',
#  'two',
#  'black',
#  'dogs',
#  'on',
#  'the',
#  'beach',
#  'A',
#  'boy',
#  'is',
#  'covered',
#  'in',
#  'bubbles',
#  'A',
#  'boy',
#  'rides',
#  'down',
#  'a',
#  'slide',
#  'into',
#  'a',
#  'small',
#  'backyard',
#  '...',
#  'A',
#  'man',
#  'in',
#  'water',
#  'throwing',
#  'a',
#  'little',
#  'boy',
#  'up',
#  'in',
#  'the',
#  '...',
#  'Two',
#  'young',
#  'boys',
#  'are',
#  'looking',
#  'at',
#  'the',
#  'camera',
#  ',',
#  'one',
#  '...',
#  'A',
#  'girl',
#  'holding',
#  'a',
#  'horse',
#  "'s",
#  'lead',
#  'behind',
#  'a',
#  'fire',
#  'A',
#  'large',
#  'skinny',
#  'dog',
#  'stands',
#  'near',
#  'two',
#  'smaller',
#  'dog',
#  '...',
#  'A',
#  'man',
#  'and',
#  'a',
#  'woman',
#  'sitting',
#  'on',
#  'a',
#  'dock',
#  'A',
#  'white',
#  'dog',
#  'has',
#  'its',
#  'head',
#  'on',
#  'the',
#  'ground',
#  'The',
#  'girl',
#  'is',
#  'climbing',
#  'a',
#  'rock',
#  'wall',
#  'A',
#  'teenage',
#  'boy',
#  'is',
#  'jumping',
#  'on',
#  'an',
#  'inflatable',
#  'slide',
#  'Several',
#  'children',
#  'playing',
#  'on',
#  'a',
#  'Polaris',
#  'vehicle',
#  '...',
#  'A',
#  'young',
#  'woman',
#  'in',
#  'a',
#  'red',
#  'sequined',
#  'costume',
#  'and',
#  'fe',
#  '...',
#  'Two',
#  'people',
#  'wearing',
#  'yellow',
#  'jackets',
#  'cross-countr',
#  '...',
#  'Two',
#  'hikers',
#  'climbing',
#  'a',
#  'snowy',
#  'hill',
#  'A',
#  'dog',
#  'is',
#  'running',
#  'down',
#  'a',
#  'road',
#  'A',
#  'woman',
#  'stands',
#  'with',
#  'children',
#  'on',
#  'a',
#  'boardwalk',
#  'at',
#  '...',
#  'A',
#  'woman',
#  'rides',
#  'a',
#  'horse',
#  'near',
#  'a',
#  'frozen',
#  'lake',
#  'in',
#  'th',
#  '...',
#  'Two',
#  'horses',
#  'are',
#  'pulling',
#  'a',
#  'woman',
#  'in',
#  'a',
#  'cart',
#  'A',
#  'person',
#  'is',
#  'climbing',
#  'a',
#  'rock',
#  'while',
#  'holding',
#  'onto',
#  '...',
#  'Spelunkers',
#  'pose',
#  'inside',
#  'a',
#  'rock',
#  'cavern',
#  'while',
#  'bat',
#  '...',
#  'People',
#  'camp',
#  'with',
#  'the',
#  'mountains',
#  'in',
#  'the',
#  'background',
#  'A',
#  'woman',
#  'stands',
#  'next',
#  'to',
#  'a',
#  'chalk',
#  'drawing',
#  'in',
#  'fron',
#  '...',
#  'a',
#  'dog',
#  'runs',
#  'through',
#  'the',
#  'snow',
#  'A',
#  'child',
#  'plays',
#  'in',
#  'a',
#  'fountain',
#  'Dog',
#  'running',
#  'out',
#  'of',
#  'tunnel',
#  'on',
#  'obstacle',
#  'course',
#  'A',
#  'yellow',
#  'dog',
#  'and',
#  'a',
#  'black',
#  'and',
#  'white',
#  'dog',
#  'are',
#  'run',
#  '...',
#  'A',
#  'young',
#  'girl',
#  'walks',
#  'on',
#  'a',
#  'railing',
#  'in',
#  'front',
#  'of',
#  'th',
#  '...',
#  'A',
#  'dog',
#  'sticking',
#  'its',
#  'face',
#  'into',
#  'the',
#  'shower',
#  'from',
#  'a',
#  '...',
#  'A',
#  'small',
#  'boy',
#  'swimming',
#  'underwater',
#  'A',
#  'young',
#  'boy',
#  'with',
#  'his',
#  'foot',
#  'outstretched',
#  'aims',
#  'a',
#  '...',
#  'A',
#  'little',
#  'boy',
#  'standing',
#  'high',
#  'in',
#  'the',
#  'air',
#  'on',
#  'a',
#  'rock',
#  'A',
#  'snowmobile',
#  'rider',
#  'flies',
#  'through',
#  'the',
#  'air',
#  'on',
#  'hi',
#  '...',
#  'Several',
#  'people',
#  'are',
#  'taking',
#  'a',
#  'break',
#  'while',
#  'on',
#  'a',
#  's',
#  '...',
#  'Three',
#  'people',
#  'on',
#  'ATV',
#  "'s",
#  'outside',
#  'A',
#  'person',
#  'is',
#  'riding',
#  'an',
#  'orange',
#  'ATV',
#  'in',
#  'a',
#  'large',
#  'em',
#  '...',
#  'An',
#  'ATV',
#  'is',
#  'airborne',
#  'over',
#  'a',
#  'field',
#  'in',
#  'front',
#  'of',
#  'a',
#  '...',
#  'A',
#  'happy',
#  'boy',
#  'is',
#  'jumping',
#  'in',
#  'front',
#  'OD',
#  'city',
#  'fountain',
#  'A',
#  'boy',
#  'walks',
#  'with',
#  'a',
#  'soccer',
#  'ball',
#  'near',
#  'a',
#  'fence',
#  'A',
#  'young',
#  'girl',
#  'painting',
#  'a',
#  'picture',
#  'A',
#  'man',
#  'on',
#  'a',
#  'mountain',
#  'bike',
#  'is',
#  'pedaling',
#  'up',
#  'a',
#  'hill',
#  'A',
#  'black',
#  'dog',
#  'pounces',
#  'to',
#  'get',
#  'a',
#  'rope',
#  'toy',
#  'A',
#  'young',
#  'girl',
#  'steadies',
#  'her',
#  'aim',
#  'with',
#  'a',
#  'camera',
#  'A',
#  'brown',
#  'and',
#  'white',
#  'dug',
#  'jumping',
#  'up',
#  'to',
#  'catch',
#  'a',
#  'Fr',
#  '...',
#  'A',
#  'small',
#  'boy',
#  'is',
#  'playing',
#  'with',
#  'rocks',
#  'A',
#  'young',
#  'man',
#  'climbs',
#  'a',
#  'rocky',
#  'hill',
#  'A',
#  'man',
#  'is',
#  'rock',
#  'climbing',
#  'a',
#  'rock',
#  'climber',
#  'climbs',
#  'a',
#  'large',
#  'rock',
#  'A',
#  'girl',
#  'looks',
#  'at',
#  'a',
#  'fountain',
#  'that',
#  'sprays',
#  'water',
#  'A',
#  'dog',
#  'is',
#  'running',
#  'on',
#  'the',
#  'beach',
#  'A',
#  'small',
#  'bird',
#  ...]

# %%
#Listado de stop words
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = set(stopwords.words('english'))
stop
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\cynthia\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
#Convertir a minúsculas.
text_str_lower = word_tokenize(text_str.lower())
print(text_str_lower)
# Out:
# ['2', 'a', 'little', 'girl', 'climbing', 'into', 'a', 'wooden', 'playhouse', '7', 'a', 'black', 'dog', 'and', 'a', 'white', 'dog', 'with', 'brown', 'spots', 'a', '...', '12', 'a', 'small', 'girl', 'in', 'the', 'grass', 'plays', 'with', 'fingerpai', '...', '17', 'a', 'man', 'sleeping', 'on', 'a', 'bench', 'outside', 'with', 'a', 'white', '...', '22', 'a', 'man', 'with', 'gauges', 'and', 'glasses', 'is', 'wearing', 'a', 'bli', '...', '27', 'a', 'little', 'girl', 'in', 'pink', 'climbs', 'a', 'rope', 'bridge', 'at', '...', '32', 'a', 'boston', 'terrier', 'is', 'running', 'in', 'the', 'grass', '37', 'dog', 'with', 'orange', 'ball', 'at', 'feet', ',', 'stands', 'on', 'shore', '...', '42', 'a', 'young', 'boy', 'runs', 'aross', 'the', 'street', '47', 'a', 'large', 'black', 'dog', 'leaps', 'a', 'fallen', 'log', '52', 'a', 'dog', 'running', 'through', 'snow', '57', 'a', 'person', 'wearing', 'skis', 'looking', 'at', 'framed', 'pictur', '...', '62', 'a', 'group', 'of', 'people', 'climbing', 'a', 'rock', 'while', 'one', 'ma', '...', '67', 'a', 'brown', 'dog', 'running', 'on', 'a', 'lawn', 'near', 'a', 'garden', 'hose', '72', 'a', 'white', 'dog', 'is', 'about', 'to', 'catch', 'a', 'yellow', 'dog', 'toy', '77', 'a', 'dog', 'leaps', 'to', 'catch', 'a', 'ball', 'in', 'a', 'field', '82', 'a', 'little', 'boy', 'at', 'a', 'lake', 'watching', 'a', 'duck', '87', 'a', 'couple', 'with', 'their', 'newborn', 'baby', 'sitting', 'under', '...', '92', 'a', 'dog', 'splashes', 'in', 'the', 'water', '97', 'a', 'person', 'in', 'the', 'snow', 'drilling', 'a', 'hole', 'in', 'the', 'ice', '102', 'two', 'dogs', 'playing', 'in', 'the', 'sand', 'at', 'the', 'beach', '107', 'an', 'ice', 'climber', 'scaling', 'a', 'frozen', 'waterfall', '112', 'a', 'black', 'dog', 'has', 'a', 'blue', 'toy', 'in', 'its', 'mouth', '117', 'a', 'man', 'and', 'child', 'kayak', 'through', 'gentle', 'waters', '122', 'a', 'brown', 'and', 'black', 'lab', 'are', 'outside', 'and', 'the', 'blac', '...', '127', 'a', 'young', 'kid', 'playing', 'the', 'goalie', 'in', 'a', 'hockey', 'rink', '132', 'a', 'man', 'sits', 'near', 'a', 'large', 'statue', '137', 'two', 'men', 'setting', 'up', 'a', 'blue', 'ice', 'fishing', 'hut', 'on', 'a', '...', '142', 'three', 'dogs', 'are', 'standing', 'in', 'the', 'grass', 'and', 'a', 'per', '...', '147', 'a', 'man', 'stands', 'in', 'front', 'of', 'a', 'very', 'tall', 'building', '152', 'a', 'small', 'boy', 'putting', 'something', 'in', 'his', 'mouth', 'wit', '...', '157', 'three', 'people', 'hang', 'out', 'on', 'top', 'of', 'a', 'big', 'hill', '162', 'a', 'boy', 'looks', 'over', 'a', 'railing', 'at', 'the', 'many', 'boats', 'a', '...', '167', 'a', 'multiracial', 'couple', 'posing', 'for', 'a', 'picture', '172', 'a', 'television', 'with', 'a', 'picture', 'of', 'a', 'girl', 'on', 'it', '177', 'a', 'group', 'of', 'teens', 'sit', 'on', 'a', 'wall', 'by', 'a', 'beach', '182', 'a', 'little', 'boy', 'skateboarder', 'is', 'doing', 'a', 'trick', 'on', '...', '187', 'a', 'woman', 'paddles', 'a', 'boat', 'down', 'a', 'river', '192', 'a', 'girl', 'with', 'pigtails', 'is', 'playing', 'in', 'the', 'ocean', 'b', '...', '197', 'a', 'group', 'of', 'young', 'children', 'playing', 'pillow', 'fight', '...', '202', 'two', 'construction', 'workers', 'sitting', 'on', 'an', 'i-beam', '207', 'two', 'boys', 'play', 'in', 'a', 'puddle', '212', 'a', 'woman', 'is', 'signaling', 'is', 'to', 'traffic', ',', 'as', 'seen', 'f', '...', '217', 'a', 'young', 'girl', 'on', 'a', 'train', 'reads', 'a', 'book', 'about', 'tra', '...', '222', 'two', 'dogs', 'playing', 'on', 'a', 'beach', '227', 'a', 'kid', 'jumps', 'off', 'the', 'diving', 'board', 'and', 'into', 'the', '...', '232', 'a', 'man', 'puts', 'his', 'shirt', 'on', 'near', 'an', 'elevator', '237', 'a', 'tan', 'dog', 'runs', 'on', 'a', 'sandy', 'beach', '242', 'a', 'young', 'boy', 'in', 'swimming', 'trunks', 'is', 'walking', 'with', '...', '247', 'a', 'skier', 'is', 'overlooking', 'a', 'snow-covered', 'mountain', '252', 'a', 'black', 'and', 'white',  ...

# %%
stopwords = [x for x in text_str_lower if x not in stop]
print(stopwords) #Aquí me di cuenta que debo quitarle números para un buen embeeding
# Out:
# ['2', 'little', 'girl', 'climbing', 'wooden', 'playhouse', '7', 'black', 'dog', 'white', 'dog', 'brown', 'spots', '...', '12', 'small', 'girl', 'grass', 'plays', 'fingerpai', '...', '17', 'man', 'sleeping', 'bench', 'outside', 'white', '...', '22', 'man', 'gauges', 'glasses', 'wearing', 'bli', '...', '27', 'little', 'girl', 'pink', 'climbs', 'rope', 'bridge', '...', '32', 'boston', 'terrier', 'running', 'grass', '37', 'dog', 'orange', 'ball', 'feet', ',', 'stands', 'shore', '...', '42', 'young', 'boy', 'runs', 'aross', 'street', '47', 'large', 'black', 'dog', 'leaps', 'fallen', 'log', '52', 'dog', 'running', 'snow', '57', 'person', 'wearing', 'skis', 'looking', 'framed', 'pictur', '...', '62', 'group', 'people', 'climbing', 'rock', 'one', '...', '67', 'brown', 'dog', 'running', 'lawn', 'near', 'garden', 'hose', '72', 'white', 'dog', 'catch', 'yellow', 'dog', 'toy', '77', 'dog', 'leaps', 'catch', 'ball', 'field', '82', 'little', 'boy', 'lake', 'watching', 'duck', '87', 'couple', 'newborn', 'baby', 'sitting', '...', '92', 'dog', 'splashes', 'water', '97', 'person', 'snow', 'drilling', 'hole', 'ice', '102', 'two', 'dogs', 'playing', 'sand', 'beach', '107', 'ice', 'climber', 'scaling', 'frozen', 'waterfall', '112', 'black', 'dog', 'blue', 'toy', 'mouth', '117', 'man', 'child', 'kayak', 'gentle', 'waters', '122', 'brown', 'black', 'lab', 'outside', 'blac', '...', '127', 'young', 'kid', 'playing', 'goalie', 'hockey', 'rink', '132', 'man', 'sits', 'near', 'large', 'statue', '137', 'two', 'men', 'setting', 'blue', 'ice', 'fishing', 'hut', '...', '142', 'three', 'dogs', 'standing', 'grass', 'per', '...', '147', 'man', 'stands', 'front', 'tall', 'building', '152', 'small', 'boy', 'putting', 'something', 'mouth', 'wit', '...', '157', 'three', 'people', 'hang', 'top', 'big', 'hill', '162', 'boy', 'looks', 'railing', 'many', 'boats', '...', '167', 'multiracial', 'couple', 'posing', 'picture', '172', 'television', 'picture', 'girl', '177', 'group', 'teens', 'sit', 'wall', 'beach', '182', 'little', 'boy', 'skateboarder', 'trick', '...', '187', 'woman', 'paddles', 'boat', 'river', '192', 'girl', 'pigtails', 'playing', 'ocean', 'b', '...', '197', 'group', 'young', 'children', 'playing', 'pillow', 'fight', '...', '202', 'two', 'construction', 'workers', 'sitting', 'i-beam', '207', 'two', 'boys', 'play', 'puddle', '212', 'woman', 'signaling', 'traffic', ',', 'seen', 'f', '...', '217', 'young', 'girl', 'train', 'reads', 'book', 'tra', '...', '222', 'two', 'dogs', 'playing', 'beach', '227', 'kid', 'jumps', 'diving', 'board', '...', '232', 'man', 'puts', 'shirt', 'near', 'elevator', '237', 'tan', 'dog', 'runs', 'sandy', 'beach', '242', 'young', 'boy', 'swimming', 'trunks', 'walking', '...', '247', 'skier', 'overlooking', 'snow-covered', 'mountain', '252', 'black', 'white', 'dog', 'jumps', 'get', 'frisbee', '257', 'man', 'laying', 'middle', 'street', 'h', '...', '262', 'one', 'dog', 'chasing', 'another', 'one', 'beach', '267', 'dog', 'jumping', 'catch', 'object', 'thrown', ',', '272', 'people', 'watching', 'hot', 'air', 'balloons', 'park', '277', 'young', 'boy', 'helmet', 'rides', 'bike', 'road', '282', 'group', 'people', 'sit', 'around', 'table', 'outside', '...', '287', 'man', 'playing', 'two', 'black', 'dogs', 'beach', '292', 'boy', 'covered', 'bubbles', '297', 'boy', 'rides', 'slide', 'small', 'backyard', '...', '302', 'man', 'water', 'throwing', 'little', 'boy', '...', '307', 'two', 'young', 'boys', 'looking', 'camera', ',', 'one', '...', '312', 'girl', 'holding', 'horse', "'s", 'lead', 'behind', 'fire', '317', 'large', 'skinny', 'dog', 'stands', 'near', 'two', 'smaller', 'dog', '...', '322', 'man', 'woman', 'sitting', 'dock', '327', 'white', 'dog', 'head', 'ground', '332', 'girl', 'climbing', 'rock', 'wall', '337', 'teenage', 'boy', 'jumping', 'inflatable', 'slide', '342', 'several', 'children', 'playing', 'polaris', 'vehicle', '...', '347', 'young', 'woman', 'red', 'sequined', 'costume', 'fe', '...', '352', 'two', 'people', 'wearing', 'yellow ...

# %%
#Agregar stopwords a la lista
sw = ['a','...','in','the','on','is','and','of',',','an','at','to']
sw
# Out:
# ['a', '...', 'in', 'the', 'on', 'is', 'and', 'of', ',', 'an', 'at', 'to']

# %%
stopwords2 = [x for x in stopwords if x not in sw]
print(stopwords2)
# Out:
# ['2', 'little', 'girl', 'climbing', 'wooden', 'playhouse', '7', 'black', 'dog', 'white', 'dog', 'brown', 'spots', '12', 'small', 'girl', 'grass', 'plays', 'fingerpai', '17', 'man', 'sleeping', 'bench', 'outside', 'white', '22', 'man', 'gauges', 'glasses', 'wearing', 'bli', '27', 'little', 'girl', 'pink', 'climbs', 'rope', 'bridge', '32', 'boston', 'terrier', 'running', 'grass', '37', 'dog', 'orange', 'ball', 'feet', 'stands', 'shore', '42', 'young', 'boy', 'runs', 'aross', 'street', '47', 'large', 'black', 'dog', 'leaps', 'fallen', 'log', '52', 'dog', 'running', 'snow', '57', 'person', 'wearing', 'skis', 'looking', 'framed', 'pictur', '62', 'group', 'people', 'climbing', 'rock', 'one', '67', 'brown', 'dog', 'running', 'lawn', 'near', 'garden', 'hose', '72', 'white', 'dog', 'catch', 'yellow', 'dog', 'toy', '77', 'dog', 'leaps', 'catch', 'ball', 'field', '82', 'little', 'boy', 'lake', 'watching', 'duck', '87', 'couple', 'newborn', 'baby', 'sitting', '92', 'dog', 'splashes', 'water', '97', 'person', 'snow', 'drilling', 'hole', 'ice', '102', 'two', 'dogs', 'playing', 'sand', 'beach', '107', 'ice', 'climber', 'scaling', 'frozen', 'waterfall', '112', 'black', 'dog', 'blue', 'toy', 'mouth', '117', 'man', 'child', 'kayak', 'gentle', 'waters', '122', 'brown', 'black', 'lab', 'outside', 'blac', '127', 'young', 'kid', 'playing', 'goalie', 'hockey', 'rink', '132', 'man', 'sits', 'near', 'large', 'statue', '137', 'two', 'men', 'setting', 'blue', 'ice', 'fishing', 'hut', '142', 'three', 'dogs', 'standing', 'grass', 'per', '147', 'man', 'stands', 'front', 'tall', 'building', '152', 'small', 'boy', 'putting', 'something', 'mouth', 'wit', '157', 'three', 'people', 'hang', 'top', 'big', 'hill', '162', 'boy', 'looks', 'railing', 'many', 'boats', '167', 'multiracial', 'couple', 'posing', 'picture', '172', 'television', 'picture', 'girl', '177', 'group', 'teens', 'sit', 'wall', 'beach', '182', 'little', 'boy', 'skateboarder', 'trick', '187', 'woman', 'paddles', 'boat', 'river', '192', 'girl', 'pigtails', 'playing', 'ocean', 'b', '197', 'group', 'young', 'children', 'playing', 'pillow', 'fight', '202', 'two', 'construction', 'workers', 'sitting', 'i-beam', '207', 'two', 'boys', 'play', 'puddle', '212', 'woman', 'signaling', 'traffic', 'seen', 'f', '217', 'young', 'girl', 'train', 'reads', 'book', 'tra', '222', 'two', 'dogs', 'playing', 'beach', '227', 'kid', 'jumps', 'diving', 'board', '232', 'man', 'puts', 'shirt', 'near', 'elevator', '237', 'tan', 'dog', 'runs', 'sandy', 'beach', '242', 'young', 'boy', 'swimming', 'trunks', 'walking', '247', 'skier', 'overlooking', 'snow-covered', 'mountain', '252', 'black', 'white', 'dog', 'jumps', 'get', 'frisbee', '257', 'man', 'laying', 'middle', 'street', 'h', '262', 'one', 'dog', 'chasing', 'another', 'one', 'beach', '267', 'dog', 'jumping', 'catch', 'object', 'thrown', '272', 'people', 'watching', 'hot', 'air', 'balloons', 'park', '277', 'young', 'boy', 'helmet', 'rides', 'bike', 'road', '282', 'group', 'people', 'sit', 'around', 'table', 'outside', '287', 'man', 'playing', 'two', 'black', 'dogs', 'beach', '292', 'boy', 'covered', 'bubbles', '297', 'boy', 'rides', 'slide', 'small', 'backyard', '302', 'man', 'water', 'throwing', 'little', 'boy', '307', 'two', 'young', 'boys', 'looking', 'camera', 'one', '312', 'girl', 'holding', 'horse', "'s", 'lead', 'behind', 'fire', '317', 'large', 'skinny', 'dog', 'stands', 'near', 'two', 'smaller', 'dog', '322', 'man', 'woman', 'sitting', 'dock', '327', 'white', 'dog', 'head', 'ground', '332', 'girl', 'climbing', 'rock', 'wall', '337', 'teenage', 'boy', 'jumping', 'inflatable', 'slide', '342', 'several', 'children', 'playing', 'polaris', 'vehicle', '347', 'young', 'woman', 'red', 'sequined', 'costume', 'fe', '352', 'two', 'people', 'wearing', 'yellow', 'jackets', 'cross-countr', '357', 'two', 'hikers', 'climbing', 'snowy', 'hill', '362', 'dog', 'running', 'road', '367', 'woman', 'stands', 'children', 'boardwalk', '372', 'woman', 'rides', 'horse', 'near', 'frozen', 'lak ...

# %%
#Frecuencia de los más representativos:
from nltk.probability import FreqDist
fdist = FreqDist(stopwords2)
fdist #Filtar el top 20
# Out:
# FreqDist({'dog': 1462, 'man': 1440, 'two': 1046, 'woman': 753, 'white': 615, 'boy': 601, 'black': 599, 'wearing': 587, 'girl': 582, 'people': 507, ...})

# %%
#Top 50 de palabras más relevantes.
fdist1 = fdist.most_common(100)
fdist1
# Out:
# [('dog', 1462),
#  ('man', 1440),
#  ('two', 1046),
#  ('woman', 753),
#  ('white', 615),
#  ('boy', 601),
#  ('black', 599),
#  ('wearing', 587),
#  ('girl', 582),
#  ('people', 507),
#  ('young', 467),
#  ('red', 438),
#  ('dogs', 435),
#  ('little', 411),
#  ('water', 375),
#  ('running', 372),
#  ('brown', 360),
#  ('playing', 360),
#  ('blue', 341),
#  ('person', 334),
#  ('three', 309),
#  ('child', 302),
#  ('small', 300),
#  ('shirt', 289),
#  ('standing', 279),
#  ('jumping', 255),
#  ('children', 239),
#  ('ball', 237),
#  ('snow', 232),
#  ('large', 226),
#  ('men', 222),
#  ('sitting', 210),
#  ('jumps', 204),
#  ('holding', 198),
#  ('grass', 197),
#  ('group', 195),
#  ('one', 192),
#  ('runs', 191),
#  ('walking', 185),
#  ('stands', 176),
#  ('green', 170),
#  ('field', 169),
#  ('front', 168),
#  ('riding', 168),
#  ('yellow', 166),
#  ('girls', 164),
#  ('play', 155),
#  ('air', 153),
#  ('beach', 146),
#  ('near', 144),
#  ('bike', 141),
#  ('rock', 131),
#  ('four', 124),
#  ('boys', 123),
#  ('outside', 120),
#  ('sits', 118),
#  ('street', 117),
#  ('plays', 116),
#  ('next', 116),
#  ('pink', 115),
#  ('orange', 115),
#  ('hat', 113),
#  ('player', 112),
#  ('women', 108),
#  ('around', 103),
#  ('walks', 103),
#  ('jacket', 103),
#  ('rides', 102),
#  ('looking', 97),
#  ('soccer', 97),
#  ('dressed', 94),
#  ('pool', 92),
#  ('skateboarder', 91),
#  ('another', 89),
#  ('mouth', 86),
#  ('camera', 84),
#  ('stand', 83),
#  ('toy', 82),
#  ('mountain', 81),
#  ('holds', 80),
#  ('football', 80),
#  ('climbing', 78),
#  ('looks', 78),
#  ('dirt', 78),
#  ('top', 77),
#  ('jump', 77),
#  ('across', 76),
#  ('along', 76),
#  ('smiling', 76),
#  ('race', 74),
#  ('w', 74),
#  ('sit', 73),
#  ('bicycle', 72),
#  ('tan', 71),
#  ('helmet', 70),
#  ('car', 69),
#  ('hair', 68),
#  ('b', 67),
#  ('stick', 67),
#  ('shorts', 67)]

# %%
# Del dataset reducido, proponemos los siguientes tipos de sujetos principales:

# Animales
# Personas adultas
# Personas jóvenes

# Animales
df_Dogs = df_new.query('descr.str.contains("dog")')
df_Cats = df_Reducido.query('descr.str.contains("cat")')

# Adultos
df_Men = df_Reducido.query('descr.object.contains("man")')
df_Women = df_Reducido.query('descr.object.contains("woman")')

# Niños
df_Boys = df_Reducido.query('descr.object.contains("boy")')
df_Girls = df_Reducido.query('descr.object.contains("girl")')

# %%
df_Dogs.to_csv(str_Path+'/Preprocessing/df_Dogs.csv', index=False, header=True)
df_Cats.to_csv(str_Path+'/Preprocessing/df_Cats.csv', index=False, header=True)
df_Men.to_csv(str_Path+'/Preprocessing/df_Men.csv', index=False, header=True)
df_Women.to_csv(str_Path+'/Preprocessing/df_Women.csv', index=False, header=True)
df_Boys.to_csv(str_Path+'/Preprocessing/df_Boys.csv', index=False, header=True)
df_Girls.to_csv(str_Path+'/Preprocessing/df_Girls.csv', index=False, header=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-6d108bfa131c> in <module>
# ----> 1 df_Dogs.to_csv(str_Path+'/Preprocessing/df_Dogs.csv', index=False, header=True)
#       2 df_Cats.to_csv(str_Path+'/Preprocessing/df_Cats.csv', index=False, header=True)
#       3 df_Men.to_csv(str_Path+'/Preprocessing/df_Men.csv', index=False, header=True)
#       4 df_Women.to_csv(str_Path+'/Preprocessing/df_Women.csv', index=False, header=True)
#       5 df_Boys.to_csv(str_Path+'/Preprocessing/df_Boys.csv', index=False, header=True)
#
# NameError: name 'df_Dogs' is not defined

# %%
# A partir de aquí, podemos ver de una manera muy general, qué tan equilibrado está el dataset

# %%
print('df_Dogs.shape: ', df_Dogs.shape)
print('df_Cats.shape: ', df_Cats.shape)
print()
print('df_Men.shape: ', df_Men.shape)
print('df_Women.shape: ', df_Women.shape)
print()
print('df_Boys.shape: ', df_Boys.shape)
print('df_Girls.shape: ', df_Girls.shape)
# Out:
# df_Dogs.shape:  (1897, 3)
# df_Cats.shape:  (149, 3)
#
# df_Men.shape:  (1839, 3)
# df_Women.shape:  (476, 3)
#
# df_Boys.shape:  (1074, 3)
# df_Girls.shape:  (922, 3)

# %%
# Como se muestra en la celda anterior, están muy desvalanceados los datos

# %%
# Del dataset reducido, proponemos los siguientes colores que podrían aparecer en escena:

# Colores de ropa u objetos:
# White, black, blue, yellow, red, green

# Colores de pelo:
# Brown, blonde

# Colores de cosas
df_White = df_Reducido.query('descr.str.contains("white")')
df_Black = df_Reducido.query('descr.str.contains("black")')
df_Blue = df_Reducido.query('descr.str.contains("blue")')
df_Yellow = df_Reducido.query('descr.str.contains("yellow")')
df_Red = df_Reducido.query('descr.str.contains("red")')
df_Green = df_Reducido.query('descr.str.contains("green")')

# Colores de pelo
df_Brown = df_Reducido.query('descr.str.contains("brown")')
df_Blonde = df_Reducido.query('descr.str.contains("blonde")')

# %%
df_White.to_csv(str_Path+'/Preprocessing/df_White.csv', index=False, header=True)
df_Black.to_csv(str_Path+'/Preprocessing/df_Black.csv', index=False, header=True)
df_Blue.to_csv(str_Path+'/Preprocessing/df_Blue.csv', index=False, header=True)
df_Yellow.to_csv(str_Path+'/Preprocessing/df_Yellow.csv', index=False, header=True)
df_Red.to_csv(str_Path+'/Preprocessing/df_Red.csv', index=False, header=True)
df_Green.to_csv(str_Path+'/Preprocessing/df_Green.csv', index=False, header=True)
df_Brown.to_csv(str_Path+'/Preprocessing/df_Brown.csv', index=False, header=True)
df_Blonde.to_csv(str_Path+'/Preprocessing/df_Blonde.csv', index=False, header=True)

# %%
print('df_White.shape: ', df_White.shape)
print('df_Black.shape: ', df_Black.shape)
print('df_Blue.shape: ', df_Blue.shape)
print('df_Yellow.shape: ', df_Yellow.shape)
print('df_Red.shape: ', df_Red.shape)
print('df_Green.shape: ', df_Green.shape)
print()
print('df_Brown.shape: ', df_Brown.shape)
print('df_Blonde.shape: ', df_Blonde.shape)
# Out:
# df_White.shape:  (830, 3)
# df_Black.shape:  (1016, 3)
# df_Blue.shape:  (461, 3)
# df_Yellow.shape:  (234, 3)
# df_Red.shape:  (730, 3)
# df_Green.shape:  (254, 3)
#
# df_Brown.shape:  (756, 3)
# df_Blonde.shape:  (76, 3)

# %%
# Los colores de cosas, parecen no estar tan desvalanceados
# Los colores de pelo sí lo están
